# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import re
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import TruncatedSVD
import pickle
import nltk
nltk.download('omw-1.4')
from nltk.corpus import stopwords
nltk.download(['wordnet', 'punkt', 'stopwords'])
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/loganvega/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/loganvega/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/loganvega/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/loganvega/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# load data from database
engine = create_engine('sqlite:///DisasterResponse.db')
df = pd.read_sql_table('disaster_response',engine)
X = df["message"] # message column fro training
Y = df.iloc[:, 4:] # 36 categories for target

#

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    """
    Function: 
        Text Split into words into a form of the root words

    Augments: 
        The input message

    Returns:
        Lemmatization a list of root-form words

    """

    # text normalize
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower())
    # tokenize
    words = word_tokenize(text)
    # stop words removal
    stopword = [w for w in words if w not in stopwords.words("english")]
    # Lemmatization process
    clean_tokens =[WordNetLemmatizer().lemmatize(w) for w in stopword]
    
    return clean_tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
# Random Forest Classifier 
pipeline_rfc = Pipeline([
        ('vect', CountVectorizer(tokenizer = tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf',  MultiOutputClassifier(RandomForestClassifier()))
    ])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
pipeline_rfc.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x7f9f0c52de50>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('clf',
#                  MultiOutputClassifier(estimator=RandomForestClassifier()))])

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
def perforamnce_scores(y_test, y_pred):
    # Testing the model
    # Printing the classification report for each label
    i = 0
    for col in y_test:
        print('Feature {}: {}'.format(i+1, col))
        print(classification_report(y_test[col], y_pred[:, i]))
        i = i + 1
    accuracy = (y_pred == y_test.values).mean()
    print('The model accuracy is {:.3f}'.format(accuracy))

# %%
# Prediction: the Random Forest Classifier  
y_pred = pipeline_rfc.predict(X_test)
perforamnce_scores(y_test, y_pred)
# Out:
# Feature 1: related
#               precision    recall  f1-score   support
#
#            0       0.69      0.41      0.51      1873
#            1       0.83      0.94      0.88      5934
#            2       0.36      0.34      0.35        58
#
#     accuracy                           0.81      7865
#    macro avg       0.63      0.56      0.58      7865
# weighted avg       0.79      0.81      0.79      7865
#
# Feature 2: request
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      6533
#            1       0.84      0.49      0.62      1332
#
#     accuracy                           0.90      7865
#    macro avg       0.87      0.74      0.78      7865
# weighted avg       0.89      0.90      0.89      7865
#
# Feature 3: offer
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7829
#            1       0.00      0.00      0.00        36
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
# Feature 4: aid_related
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.81      4646
#            1       0.74      0.69      0.72      3219
#
#     accuracy                           0.77      7865
#    macro avg       0.77      0.76      0.76      7865
# weighted avg       0.77      0.77      0.77      7865
#
# Feature 5: medical_help
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      7227
#            1       0.67      0.07      0.13       638
#
#     accuracy                           0.92      7865
#    macro avg       0.80      0.54      0.55      7865
# weighted avg       0.90      0.92      0.89      7865
#
# Feature 6: medical_products
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7447
#            1       0.84      0.08      0.14       418
#
#     accuracy                           0.95      7865
#    macro avg       0.90      0.54      0.56      7865
# weighted avg       0.94      0.95      0.93      7865
#
# Feature 7: search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7673
#            1       0.82      0.05      0.09       192
#
#     accuracy                           0.98      7865
#    macro avg       0.90      0.52      0.54      7865
# weighted avg       0.97      0.98      0.97      7865
#
# Feature 8: security
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7721
#            1       0.00      0.00      0.00       144
#
#     accuracy                           0.98      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.96      0.98      0.97      7865
#
# Feature 9: military
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      7620
#            1       0.62      0.07      0.13       245
#
#     accuracy                           0.97      7865
#    macro avg       0.80      0.54      0.56      7865
# weighted avg       0.96      0.97      0.96      7865
#
# Feature 10: child_alone
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7865
#
#     accuracy                           1.00      7865
#    macro avg       1.00      1.00      1.00      7865
# weighted avg       1.00      1.00      1.00      7865
#
# Feature 11: water
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7365
#            1       0.86      0.33      0.48       500
#
#     accuracy                           0.95      7865
#    macro avg       0.91      0.66      0.73      7865
# weighted avg       0.95      0.95      0.94      7865
#
# Feature 12: food
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      6987
#            1       0.85      0.58      0.69       878
#
#     accuracy                           0.94      7865
#    macro avg       0.90      0.78      0.83      7865
# weighted avg       0.94      0.94      0.94      7865
#
# Feature 13: shelter
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      7160
#            1       0.82      0.37      0.51       705
#
#     accuracy                           0.94      7865
#    macro avg       0.88      0.68      0.74      7865
# weighted avg       0.93      0.94      0.92      7865
#
# Feature 14: clothing
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7750
#            1       0.82      0.08      0.14       115
#
#     accuracy                           0.99      7865
#    macro avg       0.90      0.54      0.57      7865
# weighted avg       0.98      0.99      0.98      7865
#
# Feature 15: money
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7695
#            1       0.90      0.05      0.10       170
#
#     accuracy                           0.98      7865
#    macro avg       0.94      0.53      0.54      7865
# weighted avg       0.98      0.98      0.97      7865
#
# Feature 16: missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7773
#            1       1.00      0.01      0.02        92
#
#     accuracy                           0.99      7865
#    macro avg       0.99      0.51      0.51      7865
# weighted avg       0.99      0.99      0.98      7865
#
# Feature 17: refugees
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      7605
#            1       0.33      0.01      0.02       260
#
#     accuracy                           0.97      7865
#    macro avg       0.65      0.51      0.50      7865
# weighted avg       0.95      0.97      0.95      7865
#
# Feature 18: death
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7499
#            1       0.86      0.12      0.21       366
#
#     accuracy                           0.96      7865
#    macro avg       0.91      0.56      0.59      7865
# weighted avg       0.95      0.96      0.94      7865
#
# Feature 19: other_aid
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      6832
#            1       0.55      0.03      0.06      1033
#
#     accuracy                           0.87      7865
#    macro avg       0.71      0.51      0.49      7865
# weighted avg       0.83      0.87      0.82      7865
#
# Feature 20: infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      7360
#            1       0.00      0.00      0.00       505
#
#     accuracy                           0.94      7865
#    macro avg       0.47      0.50      0.48      7865
# weighted avg       0.88      0.94      0.90      7865
#
# Feature 21: transport
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7503
#            1       0.75      0.07      0.12       362
#
#     accuracy                           0.96      7865
#    macro avg       0.85      0.53      0.55      7865
# weighted avg       0.95      0.96      0.94      7865
#
# Feature 22: buildings
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7473
#            1       0.84      0.11      0.19       392
#
#     accuracy                           0.95      7865
#    macro avg       0.90      0.55      0.59      7865
# weighted avg       0.95      0.95      0.94      7865
#
# Feature 23: electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7697
#            1       0.88      0.04      0.08       168
#
#     accuracy                           0.98      7865
#    macro avg       0.93      0.52      0.53      7865
# weighted avg       0.98      0.98      0.97      7865
#
# Feature 24: tools
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7817
#            1       0.00      0.00      0.00        48
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      0.99      0.99      7865
#
# Feature 25: hospitals
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7787
#            1       0.00      0.00      0.00        78
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.98      0.99      0.99      7865
#
# Feature 26: shops
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7837
#            1       0.00      0.00      0.00        28
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
# Feature 27: aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7762
#            1       0.00      0.00      0.00       103
#
#     accuracy                           0.99      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.97      0.99      0.98      7865
#
# Feature 28: other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7524
#            1       0.00      0.00      0.00       341
#
#     accuracy                           0.96      7865
#    macro avg       0.48      0.50      0.49      7865
# weighted avg       0.92      0.96      0.94      7865
#
# Feature 29: weather_related
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      5702
#            1       0.84      0.70      0.76      2163
#
#     accuracy                           0.88      7865
#    macro avg       0.87      0.83      0.84      7865
# weighted avg       0.88      0.88      0.88      7865
#
# Feature 30: floods
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7242
#            1       0.87      0.49      0.63       623
#
#     accuracy                           0.95      7865
#    macro avg       0.91      0.74      0.80      7865
# weighted avg       0.95      0.95      0.95      7865
#
# Feature 31: storm
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      7127
#            1       0.76      0.55      0.64       738
#
#     accuracy                           0.94      7865
#    macro avg       0.86      0.77      0.80      7865
# weighted avg       0.94      0.94      0.94      7865
#
# Feature 32: fire
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7782
#            1       0.50      0.01      0.02        83
#
#     accuracy                           0.99      7865
#    macro avg       0.74      0.51      0.51      7865
# weighted avg       0.98      0.99      0.98      7865
#
# Feature 33: earthquake
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      7163
#            1       0.88      0.78      0.83       702
#
#     accuracy                           0.97      7865
#    macro avg       0.93      0.89      0.91      7865
# weighted avg       0.97      0.97      0.97      7865
#
# Feature 34: cold
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7694
#            1       0.87      0.08      0.14       171
#
#     accuracy                           0.98      7865
#    macro avg       0.92      0.54      0.56      7865
# weighted avg       0.98      0.98      0.97      7865
#
# Feature 35: other_weather
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7450
#            1       0.78      0.02      0.03       415
#
#     accuracy                           0.95      7865
#    macro avg       0.86      0.51      0.50      7865
# weighted avg       0.94      0.95      0.92      7865
#
# Feature 36: direct_report
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.91      6321
#            1       0.78      0.35      0.48      1544
#
#     accuracy                           0.85      7865
#    macro avg       0.82      0.66      0.70      7865
# weighted avg       0.84      0.85      0.83      7865
#
# The model accuracy is 0.948
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
# Using grid search
# Create Grid search parameters for Random Forest Classifier   
parameters_rfc = {
        'tfidf__use_idf': (True, False),
        'clf__estimator__n_estimators': [10, 20]
}

cv_rfc = GridSearchCV(pipeline_rfc, param_grid = parameters_rfc)
cv_rfc
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('vect',
#                                         CountVectorizer(tokenizer=<function tokenize at 0x7f9f0c52de50>)),
#                                        ('tfidf', TfidfTransformer()),
#                                        ('clf',
#                                         MultiOutputClassifier(estimator=RandomForestClassifier()))]),
#              param_grid={'clf__estimator__n_estimators': [10, 20],
#                          'tfidf__use_idf': (True, False)})

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
# Fit the first tuned model
cv_rfc.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('vect',
#                                         CountVectorizer(tokenizer=<function tokenize at 0x7f9f0c52de50>)),
#                                        ('tfidf', TfidfTransformer()),
#                                        ('clf',
#                                         MultiOutputClassifier(estimator=RandomForestClassifier()))]),
#              param_grid={'clf__estimator__n_estimators': [10, 20],
#                          'tfidf__use_idf': (True, False)})

# %%
y_pred = cv_rfc.predict(X_test)
perforamnce_scores(y_test,y_pred)
# Out:
# Feature 1: related
#               precision    recall  f1-score   support
#
#            0       0.67      0.43      0.52      1873
#            1       0.84      0.93      0.88      5934
#            2       0.29      0.40      0.34        58
#
#     accuracy                           0.80      7865
#    macro avg       0.60      0.58      0.58      7865
# weighted avg       0.79      0.80      0.79      7865
#
# Feature 2: request
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      6533
#            1       0.83      0.49      0.61      1332
#
#     accuracy                           0.90      7865
#    macro avg       0.87      0.73      0.78      7865
# weighted avg       0.89      0.90      0.88      7865
#
# Feature 3: offer
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7829
#            1       0.00      0.00      0.00        36
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
# Feature 4: aid_related
#               precision    recall  f1-score   support
#
#            0       0.77      0.84      0.80      4646
#            1       0.73      0.65      0.69      3219
#
#     accuracy                           0.76      7865
#    macro avg       0.75      0.74      0.75      7865
# weighted avg       0.76      0.76      0.76      7865
#
# Feature 5: medical_help
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      7227
#            1       0.61      0.10      0.17       638
#
#     accuracy                           0.92      7865
#    macro avg       0.77      0.55      0.56      7865
# weighted avg       0.90      0.92      0.89      7865
#
# Feature 6: medical_products
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7447
#            1       0.83      0.08      0.15       418
#
#     accuracy                           0.95      7865
#    macro avg       0.89      0.54      0.56      7865
# weighted avg       0.94      0.95      0.93      7865
#
# Feature 7: search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7673
#            1       0.57      0.04      0.08       192
#
#     accuracy                           0.98      7865
#    macro avg       0.77      0.52      0.53      7865
# weighted avg       0.97      0.98      0.97      7865
#
# Feature 8: security
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7721
#            1       0.00      0.00      0.00       144
#
#     accuracy                           0.98      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.96      0.98      0.97      7865
#
# Feature 9: military
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      7620
#            1       0.55      0.09      0.15       245
#
#     accuracy                           0.97      7865
#    macro avg       0.76      0.54      0.57      7865
# weighted avg       0.96      0.97      0.96      7865
#
# Feature 10: child_alone
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7865
#
#     accuracy                           1.00      7865
#    macro avg       1.00      1.00      1.00      7865
# weighted avg       1.00      1.00      1.00      7865
#
# Feature 11: water
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7365
#            1       0.84      0.37      0.52       500
#
#     accuracy                           0.96      7865
#    macro avg       0.90      0.68      0.75      7865
# weighted avg       0.95      0.96      0.95      7865
#
# Feature 12: food
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      6987
#            1       0.84      0.59      0.69       878
#
#     accuracy                           0.94      7865
#    macro avg       0.89      0.79      0.83      7865
# weighted avg       0.94      0.94      0.94      7865
#
# Feature 13: shelter
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      7160
#            1       0.80      0.37      0.51       705
#
#     accuracy                           0.94      7865
#    macro avg       0.87      0.68      0.74      7865
# weighted avg       0.93      0.94      0.92      7865
#
# Feature 14: clothing
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7750
#            1       0.82      0.08      0.14       115
#
#     accuracy                           0.99      7865
#    macro avg       0.90      0.54      0.57      7865
# weighted avg       0.98      0.99      0.98      7865
#
# Feature 15: money
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7695
#            1       0.55      0.04      0.07       170
#
#     accuracy                           0.98      7865
#    macro avg       0.76      0.52      0.53      7865
# weighted avg       0.97      0.98      0.97      7865
#
# Feature 16: missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7773
#            1       1.00      0.01      0.02        92
#
#     accuracy                           0.99      7865
#    macro avg       0.99      0.51      0.51      7865
# weighted avg       0.99      0.99      0.98      7865
#
# Feature 17: refugees
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      7605
#            1       0.58      0.08      0.14       260
#
#     accuracy                           0.97      7865
#    macro avg       0.78      0.54      0.56      7865
# weighted avg       0.96      0.97      0.96      7865
#
# Feature 18: death
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7499
#            1       0.85      0.14      0.24       366
#
#     accuracy                           0.96      7865
#    macro avg       0.91      0.57      0.61      7865
# weighted avg       0.95      0.96      0.94      7865
#
# Feature 19: other_aid
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      6832
#            1       0.58      0.04      0.08      1033
#
#     accuracy                           0.87      7865
#    macro avg       0.73      0.52      0.50      7865
# weighted avg       0.83      0.87      0.82      7865
#
# Feature 20: infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      7360
#            1       0.12      0.00      0.00       505
#
#     accuracy                           0.94      7865
#    macro avg       0.53      0.50      0.49      7865
# weighted avg       0.88      0.94      0.90      7865
#
# Feature 21: transport
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7503
#            1       0.70      0.08      0.14       362
#
#     accuracy                           0.96      7865
#    macro avg       0.83      0.54      0.56      7865
# weighted avg       0.95      0.96      0.94      7865
#
# Feature 22: buildings
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7473
#            1       0.82      0.12      0.21       392
#
#     accuracy                           0.95      7865
#    macro avg       0.89      0.56      0.59      7865
# weighted avg       0.95      0.95      0.94      7865
#
# Feature 23: electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7697
#            1       0.80      0.05      0.09       168
#
#     accuracy                           0.98      7865
#    macro avg       0.89      0.52      0.54      7865
# weighted avg       0.98      0.98      0.97      7865
#
# Feature 24: tools
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7817
#            1       0.00      0.00      0.00        48
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      0.99      0.99      7865
#
# Feature 25: hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7787
#            1       0.00      0.00      0.00        78
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.98      0.99      0.99      7865
#
# Feature 26: shops
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7837
#            1       0.00      0.00      0.00        28
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
# Feature 27: aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7762
#            1       0.00      0.00      0.00       103
#
#     accuracy                           0.99      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.97      0.99      0.98      7865
#
# Feature 28: other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      7524
#            1       0.33      0.00      0.01       341
#
#     accuracy                           0.96      7865
#    macro avg       0.65      0.50      0.49      7865
# weighted avg       0.93      0.96      0.94      7865
#
# Feature 29: weather_related
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91      5702
#            1       0.83      0.65      0.73      2163
#
#     accuracy                           0.87      7865
#    macro avg       0.85      0.80      0.82      7865
# weighted avg       0.86      0.87      0.86      7865
#
# Feature 30: floods
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7242
#            1       0.87      0.43      0.57       623
#
#     accuracy                           0.95      7865
#    macro avg       0.91      0.71      0.77      7865
# weighted avg       0.95      0.95      0.94      7865
#
# Feature 31: storm
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      7127
#            1       0.76      0.51      0.61       738
#
#     accuracy                           0.94      7865
#    macro avg       0.86      0.74      0.79      7865
# weighted avg       0.93      0.94      0.93      7865
#
# Feature 32: fire
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7782
#            1       0.00      0.00      0.00        83
#
#     accuracy                           0.99      7865
#    macro avg       0.49      0.50      0.50      7865
# weighted avg       0.98      0.99      0.98      7865
#
# Feature 33: earthquake
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      7163
#            1       0.88      0.76      0.81       702
#
#     accuracy                           0.97      7865
#    macro avg       0.93      0.87      0.90      7865
# weighted avg       0.97      0.97      0.97      7865
#
# Feature 34: cold
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7694
#            1       0.82      0.16      0.27       171
#
#     accuracy                           0.98      7865
#    macro avg       0.90      0.58      0.63      7865
# weighted avg       0.98      0.98      0.97      7865
#
# Feature 35: other_weather
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      7450
#            1       0.56      0.02      0.05       415
#
#     accuracy                           0.95      7865
#    macro avg       0.75      0.51      0.51      7865
# weighted avg       0.93      0.95      0.92      7865
#
# Feature 36: direct_report
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91      6321
#            1       0.74      0.33      0.45      1544
#
#     accuracy                           0.85      7865
#    macro avg       0.80      0.65      0.68      7865
# weighted avg       0.83      0.85      0.82      7865
#
# The model accuracy is 0.946
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %%
# AdaBoost Ensemble Algorithm
from sklearn.ensemble import  AdaBoostClassifier
pipeline_ada = Pipeline([
        ('vect', CountVectorizer(tokenizer = tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf',  MultiOutputClassifier(AdaBoostClassifier()))
    ])
pipeline_ada.fit(X_train, y_train)
pipeline_ada.get_params()
# Out:
# {'memory': None,
#  'steps': [('vect',
#    CountVectorizer(tokenizer=<function tokenize at 0x7f9f0c52de50>)),
#   ('tfidf', TfidfTransformer()),
#   ('clf', MultiOutputClassifier(estimator=AdaBoostClassifier()))],
#  'verbose': False,
#  'vect': CountVectorizer(tokenizer=<function tokenize at 0x7f9f0c52de50>),
#  'tfidf': TfidfTransformer(),
#  'clf': MultiOutputClassifier(estimator=AdaBoostClassifier()),
#  'vect__analyzer': 'word',
#  'vect__binary': False,
#  'vect__decode_error': 'strict',
#  'vect__dtype': numpy.int64,
#  'vect__encoding': 'utf-8',
#  'vect__input': 'content',
#  'vect__lowercase': True,
#  'vect__max_df': 1.0,
#  'vect__max_features': None,
#  'vect__min_df': 1,
#  'vect__ngram_range': (1, 1),
#  'vect__preprocessor': None,
#  'vect__stop_words': None,
#  'vect__strip_accents': None,
#  'vect__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'vect__tokenizer': <function __main__.tokenize(text)>,
#  'vect__vocabulary': None,
#  'tfidf__norm': 'l2',
#  'tfidf__smooth_idf': True,
#  'tfidf__sublinear_tf': False,
#  'tfidf__use_idf': True,
#  'clf__estimator__algorithm': 'SAMME.R',
#  'clf__estimator__base_estimator': None,
#  'clf__estimator__learning_rate': 1.0,
#  'clf__estimator__n_estimators': 50,
#  'clf__estimator__random_state': None,
#  'clf__estimator': AdaBoostClassifier(),
#  'clf__n_jobs': None}

# %%
parameters_ada = {
        'tfidf__use_idf': (True, False),
        'clf__estimator__n_estimators': [50, 60]
}

cv_ada = GridSearchCV(pipeline_ada, param_grid = parameters_ada)
cv_ada
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('vect',
#                                         CountVectorizer(tokenizer=<function tokenize at 0x7f9f0c52de50>)),
#                                        ('tfidf', TfidfTransformer()),
#                                        ('clf',
#                                         MultiOutputClassifier(estimator=AdaBoostClassifier()))]),
#              param_grid={'clf__estimator__n_estimators': [50, 60],
#                          'tfidf__use_idf': (True, False)})

# %%
cv_ada.fit(X_train, y_train)
y_pred = cv_ada.predict(X_test)
perforamnce_scores(y_test,y_pred)
# Out:
# Feature 1: related
#               precision    recall  f1-score   support
#
#            0       0.68      0.05      0.09      1873
#            1       0.76      0.99      0.86      5934
#            2       0.30      0.05      0.09        58
#
#     accuracy                           0.76      7865
#    macro avg       0.58      0.36      0.35      7865
# weighted avg       0.74      0.76      0.67      7865
#
# Feature 2: request
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94      6533
#            1       0.77      0.52      0.62      1332
#
#     accuracy                           0.89      7865
#    macro avg       0.84      0.74      0.78      7865
# weighted avg       0.89      0.89      0.88      7865
#
# Feature 3: offer
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7829
#            1       0.00      0.00      0.00        36
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      0.99      0.99      7865
#
# Feature 4: aid_related
#               precision    recall  f1-score   support
#
#            0       0.77      0.86      0.81      4646
#            1       0.76      0.62      0.68      3219
#
#     accuracy                           0.76      7865
#    macro avg       0.76      0.74      0.75      7865
# weighted avg       0.76      0.76      0.76      7865
#
# Feature 5: medical_help
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      7227
#            1       0.58      0.28      0.38       638
#
#     accuracy                           0.93      7865
#    macro avg       0.76      0.63      0.67      7865
# weighted avg       0.91      0.93      0.91      7865
#
# Feature 6: medical_products
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7447
#            1       0.68      0.30      0.42       418
#
#     accuracy                           0.96      7865
#    macro avg       0.82      0.65      0.70      7865
# weighted avg       0.95      0.96      0.95      7865
#
# Feature 7: search_and_rescue
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7673
#            1       0.50      0.15      0.23       192
#
#     accuracy                           0.98      7865
#    macro avg       0.74      0.57      0.61      7865
# weighted avg       0.97      0.98      0.97      7865
#
# Feature 8: security
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7721
#            1       0.14      0.03      0.05       144
#
#     accuracy                           0.98      7865
#    macro avg       0.56      0.51      0.52      7865
# weighted avg       0.97      0.98      0.97      7865
#
# Feature 9: military
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      7620
#            1       0.58      0.33      0.42       245
#
#     accuracy                           0.97      7865
#    macro avg       0.78      0.66      0.70      7865
# weighted avg       0.97      0.97      0.97      7865
#
# Feature 10: child_alone
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7865
#
#     accuracy                           1.00      7865
#    macro avg       1.00      1.00      1.00      7865
# weighted avg       1.00      1.00      1.00      7865
#
# Feature 11: water
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      7365
#            1       0.74      0.62      0.68       500
#
#     accuracy                           0.96      7865
#    macro avg       0.86      0.80      0.83      7865
# weighted avg       0.96      0.96      0.96      7865
#
# Feature 12: food
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      6987
#            1       0.82      0.68      0.74       878
#
#     accuracy                           0.95      7865
#    macro avg       0.89      0.83      0.86      7865
# weighted avg       0.94      0.95      0.95      7865
#
# Feature 13: shelter
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      7160
#            1       0.76      0.55      0.64       705
#
#     accuracy                           0.94      7865
#    macro avg       0.86      0.77      0.81      7865
# weighted avg       0.94      0.94      0.94      7865
#
# Feature 14: clothing
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7750
#            1       0.70      0.41      0.52       115
#
#     accuracy                           0.99      7865
#    macro avg       0.85      0.70      0.76      7865
# weighted avg       0.99      0.99      0.99      7865
#
# Feature 15: money
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      7695
#            1       0.43      0.26      0.33       170
#
#     accuracy                           0.98      7865
#    macro avg       0.71      0.63      0.66      7865
# weighted avg       0.97      0.98      0.97      7865
#
# Feature 16: missing_people
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7773
#            1       0.48      0.14      0.22        92
#
#     accuracy                           0.99      7865
#    macro avg       0.74      0.57      0.61      7865
# weighted avg       0.98      0.99      0.98      7865
#
# Feature 17: refugees
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      7605
#            1       0.57      0.24      0.34       260
#
#     accuracy                           0.97      7865
#    macro avg       0.77      0.62      0.66      7865
# weighted avg       0.96      0.97      0.96      7865
#
# Feature 18: death
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      7499
#            1       0.75      0.37      0.50       366
#
#     accuracy                           0.97      7865
#    macro avg       0.86      0.68      0.74      7865
# weighted avg       0.96      0.97      0.96      7865
#
# Feature 19: other_aid
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93      6832
#            1       0.50      0.15      0.23      1033
#
#     accuracy                           0.87      7865
#    macro avg       0.69      0.56      0.58      7865
# weighted avg       0.83      0.87      0.84      7865
#
# Feature 20: infrastructure_related
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      7360
#            1       0.44      0.10      0.16       505
#
#     accuracy                           0.93      7865
#    macro avg       0.69      0.54      0.56      7865
# weighted avg       0.91      0.93      0.91      7865
#
# Feature 21: transport
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7503
#            1       0.60      0.20      0.30       362
#
#     accuracy                           0.96      7865
#    macro avg       0.78      0.59      0.64      7865
# weighted avg       0.95      0.96      0.95      7865
#
# Feature 22: buildings
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      7473
#            1       0.71      0.39      0.50       392
#
#     accuracy                           0.96      7865
#    macro avg       0.84      0.69      0.74      7865
# weighted avg       0.96      0.96      0.96      7865
#
# Feature 23: electricity
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7697
#            1       0.60      0.23      0.33       168
#
#     accuracy                           0.98      7865
#    macro avg       0.79      0.61      0.66      7865
# weighted avg       0.98      0.98      0.98      7865
#
# Feature 24: tools
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      7817
#            1       0.00      0.00      0.00        48
#
#     accuracy                           0.99      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      0.99      0.99      7865
#
# Feature 25: hospitals
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7787
#            1       0.23      0.08      0.12        78
#
#     accuracy                           0.99      7865
#    macro avg       0.61      0.54      0.55      7865
# weighted avg       0.98      0.99      0.99      7865
#
# Feature 26: shops
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7837
#            1       0.00      0.00      0.00        28
#
#     accuracy                           1.00      7865
#    macro avg       0.50      0.50      0.50      7865
# weighted avg       0.99      1.00      0.99      7865
#
# Feature 27: aid_centers
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7762
#            1       0.21      0.07      0.10       103
#
#     accuracy                           0.98      7865
#    macro avg       0.60      0.53      0.55      7865
# weighted avg       0.98      0.98      0.98      7865
#
# Feature 28: other_infrastructure
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      7524
#            1       0.35      0.09      0.14       341
#
#     accuracy                           0.95      7865
#    macro avg       0.66      0.54      0.56      7865
# weighted avg       0.93      0.95      0.94      7865
#
# Feature 29: weather_related
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      5702
#            1       0.85      0.67      0.75      2163
#
#     accuracy                           0.88      7865
#    macro avg       0.87      0.81      0.83      7865
# weighted avg       0.88      0.88      0.87      7865
#
# Feature 30: floods
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      7242
#            1       0.84      0.59      0.69       623
#
#     accuracy                           0.96      7865
#    macro avg       0.90      0.79      0.84      7865
# weighted avg       0.96      0.96      0.96      7865
#
# Feature 31: storm
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      7127
#            1       0.75      0.50      0.60       738
#
#     accuracy                           0.94      7865
#    macro avg       0.85      0.74      0.78      7865
# weighted avg       0.93      0.94      0.93      7865
#
# Feature 32: fire
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      7782
#            1       0.47      0.22      0.30        83
#
#     accuracy                           0.99      7865
#    macro avg       0.73      0.61      0.65      7865
# weighted avg       0.99      0.99      0.99      7865
#
# Feature 33: earthquake
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      7163
#            1       0.87      0.80      0.84       702
#
#     accuracy                           0.97      7865
#    macro avg       0.93      0.90      0.91      7865
# weighted avg       0.97      0.97      0.97      7865
#
# Feature 34: cold
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      7694
#            1       0.70      0.29      0.41       171
#
#     accuracy                           0.98      7865
#    macro avg       0.84      0.64      0.70      7865
# weighted avg       0.98      0.98      0.98      7865
#
# Feature 35: other_weather
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      7450
#            1       0.44      0.15      0.23       415
#
#     accuracy                           0.95      7865
#    macro avg       0.70      0.57      0.60      7865
# weighted avg       0.93      0.95      0.93      7865
#
# Feature 36: direct_report
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91      6321
#            1       0.69      0.38      0.49      1544
#
#     accuracy                           0.85      7865
#    macro avg       0.78      0.67      0.70      7865
# weighted avg       0.83      0.85      0.83      7865
#
# The model accuracy is 0.947

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
file_name = 'classifier_ada.pkl'
with open (file_name, 'wb') as f:
    pickle.dump(cv_ada, f)

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
